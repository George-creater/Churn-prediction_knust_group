# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.preprocessing import LabelEncoder
from imblearn.over_sampling import SMOTE
import xgboost as xgb
import joblib

# %%
# Load dataset
data=pd.read_csv('/Users/george/Desktop/ml projects/call-center-data-QueryResult.csv')

# %%
data.head()
# Out:
#    recordid  customer_id  account_length  area_code  international_plan  \
# 0         1   23383607.0             101        510               False
# 1         2   22550362.0             137        510               False
# 2         3   59063354.0             103        408               False
# 3         4   25464504.0              99        415               False
# 4         5     691824.0             108        415               False
#
#    total_intl_minutes  total_intl_calls  voice_mail_plan  \
# 0                10.6                 3            False
# 1                 9.5                 7            False
# 2                13.7                 6             True
# 3                15.7                 2            False
# 4                 7.7                 4            False
#
#    number_vmail_messages  total_day_minutes  ...  total_eve_calls  \
# 0                      0               70.9  ...               73
# ...

# %%
# Drop unnecessary columns
data.drop(columns=['recordid', 'customer_id'], inplace=True)

# %%
# Encode Boolean features
data["international_plan"] = data["international_plan"].astype(int)
data["voice_mail_plan"] = data["voice_mail_plan"].astype(int)
data["churn"] = data["churn"].astype(int)

# %%
# Define features and target
X = data.drop(columns=["churn"])
y = data["churn"]

# %%
X.head()
# Out:
#    account_length  area_code  international_plan  total_intl_minutes  \
# 0             101        510                   0                10.6
# 1             137        510                   0                 9.5
# 2             103        408                   0                13.7
# 3              99        415                   0                15.7
# 4             108        415                   0                 7.7
#
#    total_intl_calls  voice_mail_plan  number_vmail_messages  \
# 0                 3                0                      0
# 1                 7                0                      0
# 2                 6                1                     29
# 3                 2                0                      0
# 4                 4                0                      0
#
#    total_day_minutes  total_day_calls  total_day_charge  total_eve_minutes  \
# 0               70.9              123             12.05              211.9
# ...

# %%
# Train test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, stratify=y, random_state=42)

# %%
X_train.shape
# Out:
# (8637, 20)

# %%
# Balance the data with smote
sm = SMOTE(random_state=42)
X_train_sm, y_train_sm = sm.fit_resample(X_train, y_train)

# %%
# Define model and hyperparameter tune it
xgb_clf = xgb.XGBClassifier(
    objective="binary:logistic",
    eval_metric="logloss",
    random_state=42
)

param_dist = {
    'n_estimators': [100, 200, 300],
    'max_depth': [3, 4, 5, 6],
    'learning_rate': [0.01, 0.05, 0.1, 0.2],
    'subsample': [0.6, 0.8, 1.0],
    'colsample_bytree': [0.6, 0.8, 1.0],
    'gamma': [0, 0.1, 0.2]
}

# %%
# Randomize Search with 5-fold CV
random_search = RandomizedSearchCV(
    xgb_clf, param_distributions=param_dist,
    n_iter=20, scoring='f1', cv=5,
    verbose=1, n_jobs=-1, random_state=42
)


random_search.fit(X_train_sm, y_train_sm)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# RandomizedSearchCV(cv=5,
#                    estimator=XGBClassifier(base_score=None, booster=None,
#                                            callbacks=None,
#                                            colsample_bylevel=None,
#                                            colsample_bynode=None,
#                                            colsample_bytree=None, device=None,
#                                            early_stopping_rounds=None,
#                                            enable_categorical=False,
#                                            eval_metric='logloss',
#                                            feature_types=None,
#                                            feature_weights=None, gamma=None,
#                                            grow_policy=None,
#                                            importance_type=None,
#                                            interaction_cons...
# ...

# %%
# Best model evaluation
best_model = random_search.best_estimator_
y_pred = best_model.predict(X_test)

print("Best Parameters:", random_search.best_params_)
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Best Parameters: {'subsample': 0.6, 'n_estimators': 300, 'max_depth': 4, 'learning_rate': 0.2, 'gamma': 0.1, 'colsample_bytree': 1.0}
#
# Confusion Matrix:
#  [[3623   30]
#  [  27  575]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      3653
#            1       0.95      0.96      0.95       602
#
#     accuracy                           0.99      4255
#    macro avg       0.97      0.97      0.97      4255
# weighted avg       0.99      0.99      0.99      4255

# %%
print("\nConfusion Matrix: ")
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='d', cmap='Blues')
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()
# Out:
# Confusion Matrix:

# %%
# Save best model
joblib.dump(best_model, "xgboost_churn_model_tuned.pkl")
# Out:
# ['xgboost_churn_model_tuned.pkl']

# %% [markdown]
# # Notes
# 	•	SMOTE was only applied to the training set.
# 	•	We’re tuning key hyperparameters with RandomizedSearchCV (faster than grid).
# 	•	Scoring is based on the F1-score, which balances precision and recall.

# %%
model = joblib.load("xgboost_churn_model_tuned.pkl")

# %%
import matplotlib.pyplot as plt
# Plot feature importance
plt.figure(figsize=(12, 8))
xgb.plot_importance(model, max_num_features=15, importance_type='gain')
plt.title("Top 15 Feature Importances (XGBoost)")
plt.tight_layout()
plt.show()

# %%
# If it's a sklearn wrapper:
booster = model.get_booster()
booster.save_model("churn_model.json")

# If it's already an xgb.Booster:
# model.save_model("churn_model.json")
